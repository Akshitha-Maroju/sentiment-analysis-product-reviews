# %%
# Install required libraries
# !pip install pandas scikit-learn flask-ngrok

# Import libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from joblib import dump

# Load your CSV file
from google.colab import files
uploaded = files.upload()  # Upload 1429_1.csv when prompted
data = pd.read_csv(next(iter(uploaded.keys())))  # Automatically reads the uploaded file

# Display data structure (verify columns)
print("Data Preview:")
print(data.head())
print("\nColumn Names:", data.columns.tolist())

# --- Data Preprocessing ---
# Replace these with your actual column names!
text_column = "reviewText"  # Change to your text column name
sentiment_column = "sentiment"  # Change to your sentiment column name

# Vectorize text
vectorizer = TfidfVectorizer(max_features=5000, stop_words="english")
X = vectorizer.fit_transform(data[text_column])
y = data[sentiment_column]

# Train model
model = SVC(kernel="linear")
model.fit(X, y)

# Save model (download to your PC)
dump(model, 'sentiment_model.pkl')
dump(vectorizer, 'vectorizer.pkl')
files.download('sentiment_model.pkl')
files.download('vectorizer.pkl')

print("Model trained and files downloaded!")
# Out:
# ...
#      <input type="file" id="files-6ac6c9d6-b12f-4564-959c-9fa22ccdbdb6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ac6c9d6-b12f-4564-959c-9fa22ccdbdb6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install required libraries
# !pip install pandas scikit-learn flask-ngrok

# Import libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from joblib import dump

# Load your CSV file
from google.colab import files
uploaded = files.upload()  # Upload 1429_1.csv when prompted
data = pd.read_csv(next(iter(uploaded.keys())))  # Automatically reads the uploaded file

# Display data structure (verify columns)
print("Data Preview:")
print(data.head())
print("\nColumn Names:", data.columns.tolist())

# --- Data Preprocessing ---
# Replace these with your actual column names!
# Examine the output of the previous print statement to find the correct column names.
# For example, if the review text column is named 'reviews.text', change 'reviewText' to 'reviews.text'.
text_column = "reviewText"  # Change to your text column name based on the column names printed above
sentiment_column = "sentiment"  # Change to your sentiment column name based on the column names printed above

# Vectorize text
# Make sure the text_column exists in your DataFrame before proceeding
if text_column in data.columns:
    vectorizer = TfidfVectorizer(max_features=5000, stop_words="english")
    X = vectorizer.fit_transform(data[text_column])
    y = data[sentiment_column]

    # Train model
    model = SVC(kernel="linear")
    model.fit(X, y)

    # Save model (download to your PC)
    dump(model, 'sentiment_model.pkl')
    dump(vectorizer, 'vectorizer.pkl')
    files.download('sentiment_model.pkl')
    files.download('vectorizer.pkl')

    print("Model trained and files downloaded!")
else:
    print(f"Error: The specified text column '{text_column}' was not found in the DataFrame.")
    print("Please check the column names printed above and update the 'text_column' variable.")
# Out:
# ...
#      <input type="file" id="files-3bdd646a-c3ed-4ad4-86b0-0f82a8d8e547" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bdd646a-c3ed-4ad4-86b0-0f82a8d8e547">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask, request, jsonify
import numpy as np

app = Flask(_name_)
run_with_ngrok(app)  # Allows public URL access

# Load model (replace with your paths)
model = load('sentiment_model.pkl')
vectorizer = load('vectorizer.pkl')

@app.route("/predict", methods=["POST"])
def predict():
    text = request.json["text"]
    X = vectorizer.transform([text])
    prediction = model.predict(X)[0]
    return jsonify({"sentiment": "Positive" if prediction == 1 else "Negative"})

app.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bd403d377b80> in <cell line: 0>()
# ----> 1 from flask_ngrok import run_with_ngrok
#       2 from flask import Flask, request, jsonify
#       3 import numpy as np
#       4
#       5 app = Flask(_name_)
#
# ModuleNotFoundError: No module named 'flask_ngrok'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Install required libraries (include installation here as well)
# !pip install flask-ngrok

from flask_ngrok import run_with_ngrok
from flask import Flask, request, jsonify
import numpy as np
from joblib import load # Import the load function

app = Flask(__name__) # Correct __name__
run_with_ngrok(app)  # Allows public URL access

# Load model (replace with your paths)
model = load('sentiment_model.pkl')
vectorizer = load('vectorizer.pkl')

@app.route("/predict", methods=["POST"])
def predict():
    text = request.json["text"]
    X = vectorizer.transform([text])
    prediction = model.predict(X)[0]
    # Assuming your sentiment column has values that map to positive/negative,
    # adjust the conditional logic based on your actual sentiment values.
    # For example, if 'positive' and 'negative' strings were used:
    # return jsonify({"sentiment": prediction})
    # If 1 is positive and 0 is negative:
    return jsonify({"sentiment": "Positive" if prediction == 1 else "Negative"})


app.run()
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-291d8276e1c4> in <cell line: 0>()
#      11
#      12 # Load model (replace with your paths)
# ---> 13 model = load('sentiment_model.pkl')
#      14 vectorizer = load('vectorizer.pkl')
#      15
#
# /usr/local/lib/python3.11/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sentiment_model.pkl'

# %%
# Install required libraries
# !pip install pandas scikit-learn flask-ngrok

# Import libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from joblib import dump, load # Import load here too
from google.colab import files # Import files here for potential download

# Load your CSV file
# In Colab, files.upload() opens a file selection dialog.
# Make sure to upload your '1429_1.csv' file.
uploaded = files.upload()
# Automatically reads the uploaded file by getting the first key (filename)
# from the dictionary returned by files.upload().
file_name = next(iter(uploaded.keys()))
data = pd.read_csv(file_name)


# Display data structure (verify columns)
print("Data Preview:")
print(data.head())
print("\nColumn Names:", data.columns.tolist())

# --- Data Preprocessing ---
# Replace these with your actual column names!
# Examine the output of the previous print statement to find the correct column names.
# For example, if the review text column is named 'reviews.text', change 'reviewText' to 'reviews.text'.
text_column = "reviewText"  # Change to your text column name based on the column names printed above
sentiment_column = "sentiment"  # Change to your sentiment column name based on the column names printed above

# Vectorize text
# Make sure the text_column exists in your DataFrame before proceeding
if text_column in data.columns and sentiment_column in data.columns:
    vectorizer = TfidfVectorizer(max_features=5000, stop_words="english")
    X = vectorizer.fit_transform(data[text_column])
    y = data[sentiment_column]

    # Train model
    model = SVC(kernel="linear")
    model.fit(X, y)

    # Save model and vectorizer
    # These files will be saved in the current Colab session's file system.
    dump(model, 'sentiment_model.pkl')
    dump(vectorizer, 'vectorizer.pkl')

    # Optional: Download the files to your local machine
    #files.download('sentiment_model.pkl')
    #files.download('vectorizer.pkl')

    print("Model trained and files saved (and potentially downloaded)!")
else:
    print(f"Error: The specified text column '{text_column}' or sentiment column '{sentiment_column}' was not found in the DataFrame.")
    print("Please check the column names printed above and update the 'text_column' and 'sentiment_column' variables.")
# Out:
# ...
#      <input type="file" id="files-6fcff3b7-0031-41a4-8fe3-00b79ed985af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fcff3b7-0031-41a4-8fe3-00b79ed985af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
